# %% [markdown]
# <a href="https://colab.research.google.com/github/PoYaSharonLin/EEGClassification/blob/updated-CNN/EEGClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.fft as fft
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import signal
import sklearn
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torchvision
import torchaudio
from torchvision import transforms
import cv2
# %matplotlib inline
from utils_v1 import MindBigData, GetDataSet, GetDataLoaders, GetDataLoadersEEGImages, GetDataAndPreProcess
import time


seed = 123
np.random.seed(seed)
torch.manual_seed(seed)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-411bd6453126> in <cell line: 0>()
#      28
#      29 from google.colab import drive
# ---> 30 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     197       raise ValueError('Mountpoint must not be a symlink')
#     198     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# --> 199       raise ValueError('Mountpoint must not already contain files')
#     200     if not _os.path.isdir(mountpoint) and _os.path.exists(mountpoint):
#     201       raise ValueError('Mountpoint must either be a directory or not exist')
#
# ValueError: Mountpoint must not already contain files

# %%
# Uninstall the pre-installed NumPy (optional)
# !pip uninstall -y numpy

# !pip install numpy==2.0.0
# !pip install scipy>=1.14

import numpy as np
print(np.__version__)
# Out:
# Found existing installation: numpy 2.2.5
# Uninstalling numpy-2.2.5:
#   Successfully uninstalled numpy-2.2.5
# Collecting numpy==2.0.0
#   Downloading numpy-2.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 5.5 MB/s eta 0:00:00
# Downloading numpy-2.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 114.5 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.0.0
# 2.0.2

# %%
# download dataset to google drive
def DownloadDataSet(link, drive_path, colab_path, filename):
    ! wget -c -P "{drive_path}" "{link}"
    # !unzip "{drive_path}/{filename}" -d "{drive_path}"
    # !cp -r "{drive_path}" "{colab_path}"

# %%
link = 'http://www.mindbigdata.com/opendb/MindBigData-EP-v1.0.zip'
drive_path = '/content/drive/MyDrive/113-2/BCI/data'
colab_path = '.'

DownloadDataSet(link, drive_path, colab_path,"MindBigData-EP-v1.0.zip")
# Out:
# --2025-04-23 04:24:45--  http://www.mindbigdata.com/opendb/MindBigData-EP-v1.0.zip
# Resolving www.mindbigdata.com (www.mindbigdata.com)... 150.136.107.169
# Connecting to www.mindbigdata.com (www.mindbigdata.com)|150.136.107.169|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://mindbigdata.com/opendb/MindBigData-EP-v1.0.zip [following]
# --2025-04-23 04:24:46--  https://mindbigdata.com/opendb/MindBigData-EP-v1.0.zip
# Resolving mindbigdata.com (mindbigdata.com)... 150.136.107.169
# Connecting to mindbigdata.com (mindbigdata.com)|150.136.107.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 427958689 (408M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/113-2/BCI/data/MindBigData-EP-v1.0.zip’
#
# MindBigData-EP-v1.0 100%[===================>] 408.13M  16.4MB/s    in 28s
#
# 2025-04-23 04:25:15 (14.8 MB/s) - ‘/content/drive/MyDrive/113-2/BCI/data/MindBigData-EP-v1.0.zip’ saved [427958689/427958689]
#
# Archive:  /content/drive/MyDrive/113-2/BCI/data/MindBigData-EP-v1.0.zip
#   inflating: /content/drive/MyDrive/113-2/BCI/data/EP1.01.txt

# %%
x, y = GetDataAndPreProcess(input_file="data/EP1.01.txt", samples_per_digit=6500)
# Out:
# [6466, 6324, 6443, 6500, 6304, 6500, 6478, 6293, 6494, 6500]

# %%
train_loader, valid_loader, test_loader = GetDataLoaders(x, y, batch_size=64)

# %%
# Display 2 signals with their labels
# replace .next() with next() in Python3
data_iter = iter(train_loader)
inputs, labels = next(data_iter)
EEGChannel = ["AF3", "F7", "F3", "FC5", "T7", "P7", "O1", "O2", "P8", "T8", "FC6", "F4", "F8", "AF4"]

fig = plt.figure(figsize=(20, 15))
fig.suptitle('EEG signals', fontsize=16)
for i in range(2):
    for j in range(14):
        ax = fig.add_subplot(14, 2, i + 1 + 2 * j)
        if (j == 0):
            ax.set_title(
                'digit seen by patient: ' + str(labels[i].item()))  # .item() gets the value contained in a tensor
        ax.plot(inputs[i][j])
        ax.set_xlabel('samples')
        ax.set_ylabel(EEGChannel[j])
        ax.grid()

# %%
# Display 2 FFT of signals with their labels
f = np.arange(-112, 112) * 0.5
fig = plt.figure(figsize=(20, 15))
fig.suptitle('FFT of EEG signals', fontsize=16)
for i in range(2):
    for j in range(14):
        ax = fig.add_subplot(14, 2, i + 1 + 2 * j)
        if (j == 0):
            ax.set_title(
                'digit seen by patient: ' + str(labels[i].item()))  # .item() gets the value contained in a tensor
        ax.plot(f, abs(fft.fftshift(fft.fft(inputs[i][j]))))
        ax.set_xlabel('frequencies')
        ax.set_ylabel(EEGChannel[j])
        ax.grid()

# %%
class CNN(nn.Module):
    def __init__(self, num_channel=10, num_classes=4, signal_length=1000,
                 filters_n1=4, kernel_window_eeg=39, kernel_window=19,
                 conv_3_dilation=4, conv_4_dilation=4):
        super().__init__()

        filters = [filters_n1, filters_n1 * 2]

        self.conv_1 = Conv2dBlockELU(in_ch=1, out_ch=filters[0], kernel_size=(1, kernel_window_eeg), w_in=signal_length)

        self.conv_1_1 = Conv2dBlockELU(in_ch=filters[0], out_ch=filters[0], kernel_size=(1, kernel_window_eeg), w_in=self.conv_1.w_out)

        self.conv_2 = Conv2dBlockELU(in_ch=filters[0], out_ch=filters[0], kernel_size=(num_channel, 1))

        self.conv_3 = Conv2dBlockELU(in_ch=filters[0], out_ch=filters[1], kernel_size=(1, kernel_window),
                                     padding=(0,conv_3_dilation-1), dilation=(1,conv_3_dilation), w_in=self.conv_1.w_out)

        self.conv_4 = Conv2dBlockELU(in_ch=filters[1], out_ch=filters[1], kernel_size=(1, kernel_window),
                                     padding=(0,conv_4_dilation-1), dilation=(1,conv_4_dilation), w_in=self.conv_3.w_out)

        self.fc_layer = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(480, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 10),
        )

        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = torch.unsqueeze(x, 1)

        # conv layers
        x = self.conv_1(x)
        x = self.conv_1_1(x)
        x = self.conv_2(x)
        x = self.dropout(x)
        x = self.conv_3(x)
        x = self.conv_4(x)
        x = self.dropout(x)

        # flatten
        x = x.view(x.size(0), -1)

        # fc layers
        x = self.fc_layer(x)

        return x


class Conv2dBlockELU(nn.Module):
    def __init__(self, in_ch, out_ch, kernel_size, padding=(0,0), dilation=(1,1), groups=1, w_in=None):
        super(Conv2dBlockELU, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=kernel_size, padding=padding, dilation=dilation, groups=groups),
            nn.BatchNorm2d(out_ch),
            nn.ELU(inplace=True)
        )

        if w_in is not None:
            self.w_out = int( ((w_in + 2 * padding[1] - dilation[1] * (kernel_size[1]-1)-1) / 1) + 1 )

        self.out_ch = out_ch

    def forward(self, x):
        return self.conv(x)

# %%
model = CNN(
        num_channel = 14,
        num_classes = 10,
        signal_length = 224,
        kernel_window_eeg = 32,
        filters_n1 = 8,
    ).to(device)
print("Model Architecture:")
print(model)
# Out:
# Model Architecture:
# CNN(
#   (conv_1): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(1, 8, kernel_size=(1, 32), stride=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (conv_1_1): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(8, 8, kernel_size=(1, 32), stride=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (conv_2): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(8, 8, kernel_size=(14, 1), stride=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (conv_3): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(8, 16, kernel_size=(1, 19), stride=(1, 1), padding=(0, 3), dilation=(1, 4))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (conv_4): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(16, 16, kernel_size=(1, 19), stride=(1, 1), padding=(0, 3), dilation=(1, 4))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (fc_layer): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=480, out_features=256, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
### Helper Functions ###
# function to calcualte accuracy of the model
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement.
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

def calculate_accuracy(model, dataloader, device, criterion):
    model.eval() # put in evaluation mode
    total_correct = 0
    total_images = 0
    running_loss = 0.0
    confusion_matrix = np.zeros([10,10], int)
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images = images.float()
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels) # calculate the loss
            running_loss += loss.data.item()
            _, predicted = torch.max(outputs.data, 1)
            total_images += labels.size(0)
            total_correct += (predicted == labels).sum().item()
            for i, l in enumerate(labels):
                confusion_matrix[l.item(), predicted[i].item()] += 1

    # Normalizing the loss by the total number of train batches
    running_loss /= len(dataloader)
    model_accuracy = total_correct / total_images * 100
    return model_accuracy, confusion_matrix, running_loss

# use a different initialization for the model
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Linear') != -1:
        nn.init.normal_(m.bias, 0, 0.005)
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

# %%
def compile_model(model):
    # hyper-parameters
    learning_rate = 0.06
    epochs = 200
    weight_decay = 9e-4
    batch_size = 215

    # get data loaders
    train_loader, valid_loader, test_loader = GetDataLoaders(x, y, batch_size)

    # loss criterion
    criterion = nn.CrossEntropyLoss()

    # optimizer - SGD, Adam, RMSProp...
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,
                                    weight_decay=weight_decay)

    # Learning Rate Scheduler
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5,
                                  verbose=True)

    # Early Stopping
    early_stopping = EarlyStopping(delta=0.00, patience=10, verbose=True)

    # training loop
    train_losses = []
    valid_losses = []
    for epoch in range(1, epochs + 1):
        model.train() # put in training mode
        running_loss = 0.0
        total_correct = 0
        total_images = 0
        epoch_time = time.time()
        for train_data in train_loader:
            # get the inputs
            inputs, labels = train_data
            # send them to device
            inputs = inputs.to(device)
            labels = labels.to(device)

            # forward + backward + optimize
            outputs = model(inputs) # forward pass
            loss = criterion(outputs, labels) # calculate the loss

            # always the same 3 steps
            loss.backward() # backpropagation
            optimizer.step() # update parameters
            optimizer.zero_grad() # zero the parameter gradients

            # calc accuracy
            _, predicted = torch.max(outputs.data, 1)
            total_images += labels.size(0)
            total_correct += (predicted == labels).sum().item()

            # print statistics
            running_loss += loss.data.item()

        # Normalizing the loss by the total number of train batches
        running_loss /= len(train_loader)
        train_losses.append(running_loss)

        # Calculate training/test set accuracy of the existing model
        train_accuracy = total_correct / total_images * 100
        valid_accuracy, _, valid_loss = calculate_accuracy(model, valid_loader, device, criterion)
        valid_losses.append(valid_loss)

        log = "Epoch: {} | Train Loss: {:.4f} | Training accuracy: {:.3f}% | Validation Loss: {:.3f} | Validation accuracy: {:.3f}% | ".format(epoch
        , running_loss, train_accuracy, valid_loss, valid_accuracy)
        epoch_time = time.time() - epoch_time
        log += "Epoch Time: {:.2f} secs".format(epoch_time)
        print(log)

        # accuracy is used to track down a plateau
        scheduler.step(valid_loss)

        # Early Stopping
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            break

    print('==> Finished Training ...')

    # calculate accuracy and confusion matrix
    test_accuracy, confusion_matrix, _ = calculate_accuracy(model, test_loader, device, criterion)
    print("test accuracy: {:.3f}%".format(test_accuracy))

    # plot confusion matrix
    fig, ax = plt.subplots(1,1,figsize=(8,6))
    ax.matshow(confusion_matrix, aspect='auto', vmin=0, vmax=1000, cmap=plt.get_cmap('Blues'))
    plt.ylabel('Actual Category')
    plt.yticks(range(10), range(10))
    plt.xlabel('Predicted Category')
    plt.xticks(range(10), range(10))
    plt.show()

    # print loss curves
    plt.plot(train_losses, label='Train Loss')
    plt.plot(valid_losses, label='Validation Loss')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss')

# %%
model = CNN(
        num_channel = 14,
        num_classes = 10,
        signal_length = 224,
        kernel_window_eeg = 32,
        filters_n1 = 8,
    ).to(device)
compile_model(model=model)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch: 1 | Train Loss: 2.3193 | Training accuracy: 10.158% | Validation Loss: 2.299 | Validation accuracy: 11.509% | Epoch Time: 12.83 secs
# Validation loss decreased (inf --> 2.298717).  Saving model ...
# Epoch: 2 | Train Loss: 2.2972 | Training accuracy: 12.093% | Validation Loss: 2.289 | Validation accuracy: 12.867% | Epoch Time: 11.49 secs
# Validation loss decreased (2.298717 --> 2.288986).  Saving model ...
# Epoch: 3 | Train Loss: 2.2858 | Training accuracy: 13.547% | Validation Loss: 2.281 | Validation accuracy: 13.821% | Epoch Time: 11.80 secs
# Validation loss decreased (2.288986 --> 2.281068).  Saving model ...
# Epoch: 4 | Train Loss: 2.2782 | Training accuracy: 13.980% | Validation Loss: 2.275 | Validation accuracy: 14.256% | Epoch Time: 11.69 secs
# Validation loss decreased (2.281068 --> 2.275466).  Saving model ...
# Epoch: 5 | Train Loss: 2.2738 | Training accuracy: 14.542% | Validation Loss: 2.274 | Validation accuracy: 14.546% | Epoch Time: 11.97 secs
# Validation loss decreased (2.275466 --> 2.274067).  Saving model ...
# Epoch: 6 | Train Loss: 2.2682 | Training accuracy: 14.801% | Validation Loss: 2.269 | Validation accuracy: 14.930% | Epoch Time: 12.40 secs
# Validation loss decreased (2.274067 --> 2.269470).  Saving model ...
# Epoch: 7 | Train Loss: 2.2619 | Training accuracy: 15.228% | Validation Loss: 2.266 | Validation accuracy: 15.324% | Epoch Time: 12.14 secs
# Validation loss decreased (2.269470 --> 2.265693).  Saving model ...
# Epoch: 8 | Train Loss: 2.2604 | Training accuracy: 15.452% | Validation Loss: 2.264 | Validation accuracy: 15.500% | Epoch Time: 12.26 secs
# Validation loss decreased (2.265693 --> 2.264292).  Saving model ...
# Epoch: 9 | Train Loss: 2.2566 | Training accuracy: 15.672% | Validation Loss: 2.259 | Validation accuracy: 15.842% | Epoch Time: 12.16 secs
# Validation loss decreased (2.264292 --> 2.258933).  Saving model ...
# Epoch: 10 | Train Loss: 2.2528 | Training accuracy: 15.747% | Validation Loss: 2.257 | Validation accuracy: 15.728% | Epoch Time: 12.05 secs
# Validation loss decreased (2.258933 --> 2.256834).  Saving model ...
# Epoch: 11 | Train Loss: 2.2486 | Training accuracy: 16.352% | Validation Loss: 2.252 | Validation accuracy: 16.153% | Epoch Time: 12.05 secs
# Validation loss decreased (2.256834 --> 2.251589).  Saving model ...
# Epoch: 12 | Train Loss: 2.2451 | Training accuracy: 16.448% | Validation Loss: 2.248 | Validation accuracy: 15.998% | Epoch Time: 12.16 secs
# Validation loss decreased (2.251589 --> 2.247926).  Saving model ...
# Epoch: 13 | Train Loss: 2.2420 | Training accuracy: 16.723% | Validation Loss: 2.250 | Validation accuracy: 16.299% | Epoch Time: 12.10 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 14 | Train Loss: 2.2404 | Training accuracy: 16.951% | Validation Loss: 2.246 | Validation accuracy: 16.226% | Epoch Time: 12.08 secs
# Validation loss decreased (2.247926 --> 2.245803).  Saving model ...
# Epoch: 15 | Train Loss: 2.2385 | Training accuracy: 16.767% | Validation Loss: 2.245 | Validation accuracy: 16.226% | Epoch Time: 12.13 secs
# Validation loss decreased (2.245803 --> 2.245096).  Saving model ...
# Epoch: 16 | Train Loss: 2.2359 | Training accuracy: 17.086% | Validation Loss: 2.242 | Validation accuracy: 16.392% | Epoch Time: 12.15 secs
# Validation loss decreased (2.245096 --> 2.241813).  Saving model ...
# Epoch: 17 | Train Loss: 2.2338 | Training accuracy: 17.119% | Validation Loss: 2.235 | Validation accuracy: 17.377% | Epoch Time: 12.12 secs
# Validation loss decreased (2.241813 --> 2.235462).  Saving model ...
# Epoch: 18 | Train Loss: 2.2312 | Training accuracy: 17.267% | Validation Loss: 2.239 | Validation accuracy: 16.516% | Epoch Time: 12.23 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 19 | Train Loss: 2.2286 | Training accuracy: 17.439% | Validation Loss: 2.241 | Validation accuracy: 16.288% | Epoch Time: 12.15 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 20 | Train Loss: 2.2270 | Training accuracy: 17.520% | Validation Loss: 2.235 | Validation accuracy: 17.252% | Epoch Time: 12.07 secs
# Validation loss decreased (2.235462 --> 2.234762).  Saving model ...
# Epoch: 21 | Train Loss: 2.2244 | Training accuracy: 17.569% | Validation Loss: 2.235 | Validation accuracy: 17.035% | Epoch Time: 12.07 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 22 | Train Loss: 2.2230 | Training accuracy: 17.652% | Validation Loss: 2.233 | Validation accuracy: 17.118% | Epoch Time: 12.08 secs
# Validation loss decreased (2.234762 --> 2.233226).  Saving model ...
# Epoch: 23 | Train Loss: 2.2198 | Training accuracy: 17.901% | Validation Loss: 2.231 | Validation accuracy: 17.273% | Epoch Time: 12.09 secs
# Validation loss decreased (2.233226 --> 2.230646).  Saving model ...
# Epoch: 24 | Train Loss: 2.2181 | Training accuracy: 17.845% | Validation Loss: 2.237 | Validation accuracy: 17.138% | Epoch Time: 12.24 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 25 | Train Loss: 2.2158 | Training accuracy: 18.295% | Validation Loss: 2.224 | Validation accuracy: 17.626% | Epoch Time: 12.14 secs
# Validation loss decreased (2.230646 --> 2.223836).  Saving model ...
# Epoch: 26 | Train Loss: 2.2155 | Training accuracy: 18.243% | Validation Loss: 2.222 | Validation accuracy: 17.532% | Epoch Time: 12.05 secs
# Validation loss decreased (2.223836 --> 2.222490).  Saving model ...
# Epoch: 27 | Train Loss: 2.2105 | Training accuracy: 18.378% | Validation Loss: 2.220 | Validation accuracy: 17.895% | Epoch Time: 12.07 secs
# Validation loss decreased (2.222490 --> 2.219668).  Saving model ...
# Epoch: 28 | Train Loss: 2.2086 | Training accuracy: 18.575% | Validation Loss: 2.217 | Validation accuracy: 18.206% | Epoch Time: 12.28 secs
# Validation loss decreased (2.219668 --> 2.217183).  Saving model ...
# Epoch: 29 | Train Loss: 2.2056 | Training accuracy: 18.768% | Validation Loss: 2.214 | Validation accuracy: 18.248% | Epoch Time: 12.07 secs
# Validation loss decreased (2.217183 --> 2.214250).  Saving model ...
# Epoch: 30 | Train Loss: 2.2050 | Training accuracy: 18.863% | Validation Loss: 2.212 | Validation accuracy: 18.704% | Epoch Time: 12.21 secs
# Validation loss decreased (2.214250 --> 2.212495).  Saving model ...
# Epoch: 31 | Train Loss: 2.1997 | Training accuracy: 18.905% | Validation Loss: 2.217 | Validation accuracy: 17.906% | Epoch Time: 12.19 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 32 | Train Loss: 2.1988 | Training accuracy: 19.058% | Validation Loss: 2.212 | Validation accuracy: 18.092% | Epoch Time: 12.07 secs
# Validation loss decreased (2.212495 --> 2.211731).  Saving model ...
# Epoch: 33 | Train Loss: 2.1983 | Training accuracy: 19.044% | Validation Loss: 2.203 | Validation accuracy: 19.388% | Epoch Time: 12.09 secs
# Validation loss decreased (2.211731 --> 2.203405).  Saving model ...
# Epoch: 34 | Train Loss: 2.1950 | Training accuracy: 19.309% | Validation Loss: 2.220 | Validation accuracy: 18.175% | Epoch Time: 12.10 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 35 | Train Loss: 2.1946 | Training accuracy: 19.145% | Validation Loss: 2.203 | Validation accuracy: 18.839% | Epoch Time: 12.09 secs
# Validation loss decreased (2.203405 --> 2.202954).  Saving model ...
# Epoch: 36 | Train Loss: 2.1902 | Training accuracy: 19.568% | Validation Loss: 2.202 | Validation accuracy: 18.787% | Epoch Time: 12.15 secs
# Validation loss decreased (2.202954 --> 2.201763).  Saving model ...
# Epoch: 37 | Train Loss: 2.1886 | Training accuracy: 19.512% | Validation Loss: 2.203 | Validation accuracy: 18.580% | Epoch Time: 12.18 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 38 | Train Loss: 2.1884 | Training accuracy: 19.597% | Validation Loss: 2.204 | Validation accuracy: 18.528% | Epoch Time: 12.12 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 39 | Train Loss: 2.1877 | Training accuracy: 19.703% | Validation Loss: 2.201 | Validation accuracy: 19.036% | Epoch Time: 12.06 secs
# Validation loss decreased (2.201763 --> 2.201366).  Saving model ...
# Epoch: 40 | Train Loss: 2.1870 | Training accuracy: 19.593% | Validation Loss: 2.203 | Validation accuracy: 18.922% | Epoch Time: 12.07 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 41 | Train Loss: 2.1839 | Training accuracy: 19.817% | Validation Loss: 2.201 | Validation accuracy: 18.663% | Epoch Time: 12.11 secs
# Validation loss decreased (2.201366 --> 2.201032).  Saving model ...
# Epoch: 42 | Train Loss: 2.1840 | Training accuracy: 20.008% | Validation Loss: 2.198 | Validation accuracy: 19.139% | Epoch Time: 12.14 secs
# Validation loss decreased (2.201032 --> 2.198289).  Saving model ...
# Epoch: 43 | Train Loss: 2.1836 | Training accuracy: 19.801% | Validation Loss: 2.192 | Validation accuracy: 19.274% | Epoch Time: 12.22 secs
# Validation loss decreased (2.198289 --> 2.191969).  Saving model ...
# Epoch: 44 | Train Loss: 2.1825 | Training accuracy: 19.944% | Validation Loss: 2.200 | Validation accuracy: 19.036% | Epoch Time: 12.17 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 45 | Train Loss: 2.1800 | Training accuracy: 19.991% | Validation Loss: 2.206 | Validation accuracy: 18.694% | Epoch Time: 12.07 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 46 | Train Loss: 2.1781 | Training accuracy: 20.022% | Validation Loss: 2.191 | Validation accuracy: 19.513% | Epoch Time: 12.07 secs
# Validation loss decreased (2.191969 --> 2.190685).  Saving model ...
# Epoch: 47 | Train Loss: 2.1793 | Training accuracy: 20.215% | Validation Loss: 2.211 | Validation accuracy: 18.445% | Epoch Time: 12.07 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 48 | Train Loss: 2.1772 | Training accuracy: 20.176% | Validation Loss: 2.192 | Validation accuracy: 19.274% | Epoch Time: 12.06 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 49 | Train Loss: 2.1789 | Training accuracy: 20.180% | Validation Loss: 2.191 | Validation accuracy: 19.243% | Epoch Time: 12.19 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 50 | Train Loss: 2.1765 | Training accuracy: 20.288% | Validation Loss: 2.195 | Validation accuracy: 19.793% | Epoch Time: 12.39 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 51 | Train Loss: 2.1745 | Training accuracy: 20.443% | Validation Loss: 2.190 | Validation accuracy: 19.689% | Epoch Time: 12.06 secs
# Validation loss decreased (2.190685 --> 2.189527).  Saving model ...
# Epoch: 52 | Train Loss: 2.1739 | Training accuracy: 20.545% | Validation Loss: 2.192 | Validation accuracy: 19.637% | Epoch Time: 12.12 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 53 | Train Loss: 2.1730 | Training accuracy: 20.493% | Validation Loss: 2.192 | Validation accuracy: 19.824% | Epoch Time: 12.10 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 54 | Train Loss: 2.1728 | Training accuracy: 20.356% | Validation Loss: 2.189 | Validation accuracy: 19.575% | Epoch Time: 12.09 secs
# Validation loss decreased (2.189527 --> 2.188872).  Saving model ...
# Epoch: 55 | Train Loss: 2.1729 | Training accuracy: 20.418% | Validation Loss: 2.190 | Validation accuracy: 20.124% | Epoch Time: 12.20 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 56 | Train Loss: 2.1719 | Training accuracy: 20.485% | Validation Loss: 2.188 | Validation accuracy: 19.596% | Epoch Time: 12.17 secs
# Validation loss decreased (2.188872 --> 2.187863).  Saving model ...
# Epoch: 57 | Train Loss: 2.1698 | Training accuracy: 20.541% | Validation Loss: 2.193 | Validation accuracy: 19.596% | Epoch Time: 12.04 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 58 | Train Loss: 2.1704 | Training accuracy: 20.385% | Validation Loss: 2.189 | Validation accuracy: 19.927% | Epoch Time: 12.10 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 59 | Train Loss: 2.1661 | Training accuracy: 20.841% | Validation Loss: 2.191 | Validation accuracy: 19.730% | Epoch Time: 12.11 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 60 | Train Loss: 2.1686 | Training accuracy: 20.659% | Validation Loss: 2.185 | Validation accuracy: 19.699% | Epoch Time: 12.11 secs
# Validation loss decreased (2.187863 --> 2.185063).  Saving model ...
# Epoch: 61 | Train Loss: 2.1679 | Training accuracy: 20.549% | Validation Loss: 2.187 | Validation accuracy: 19.689% | Epoch Time: 12.11 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 62 | Train Loss: 2.1686 | Training accuracy: 20.962% | Validation Loss: 2.189 | Validation accuracy: 19.824% | Epoch Time: 12.18 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 63 | Train Loss: 2.1653 | Training accuracy: 20.709% | Validation Loss: 2.185 | Validation accuracy: 19.627% | Epoch Time: 12.14 secs
# Validation loss decreased (2.185063 --> 2.184883).  Saving model ...
# Epoch: 64 | Train Loss: 2.1667 | Training accuracy: 20.883% | Validation Loss: 2.190 | Validation accuracy: 19.596% | Epoch Time: 12.09 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 65 | Train Loss: 2.1662 | Training accuracy: 20.686% | Validation Loss: 2.188 | Validation accuracy: 19.575% | Epoch Time: 12.10 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 66 | Train Loss: 2.1634 | Training accuracy: 20.937% | Validation Loss: 2.192 | Validation accuracy: 19.088% | Epoch Time: 12.05 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 67 | Train Loss: 2.1550 | Training accuracy: 21.376% | Validation Loss: 2.182 | Validation accuracy: 20.218% | Epoch Time: 12.04 secs
# Validation loss decreased (2.184883 --> 2.181523).  Saving model ...
# Epoch: 68 | Train Loss: 2.1538 | Training accuracy: 21.368% | Validation Loss: 2.178 | Validation accuracy: 20.425% | Epoch Time: 12.18 secs
# Validation loss decreased (2.181523 --> 2.177665).  Saving model ...
# Epoch: 69 | Train Loss: 2.1533 | Training accuracy: 21.636% | Validation Loss: 2.180 | Validation accuracy: 20.104% | Epoch Time: 12.15 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 70 | Train Loss: 2.1522 | Training accuracy: 21.621% | Validation Loss: 2.180 | Validation accuracy: 20.332% | Epoch Time: 12.10 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 71 | Train Loss: 2.1521 | Training accuracy: 21.393% | Validation Loss: 2.180 | Validation accuracy: 20.249% | Epoch Time: 12.13 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 72 | Train Loss: 2.1492 | Training accuracy: 21.891% | Validation Loss: 2.180 | Validation accuracy: 20.114% | Epoch Time: 12.32 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 73 | Train Loss: 2.1499 | Training accuracy: 21.656% | Validation Loss: 2.180 | Validation accuracy: 20.207% | Epoch Time: 12.82 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 74 | Train Loss: 2.1495 | Training accuracy: 21.683% | Validation Loss: 2.181 | Validation accuracy: 20.259% | Epoch Time: 12.24 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 75 | Train Loss: 2.1460 | Training accuracy: 21.795% | Validation Loss: 2.176 | Validation accuracy: 20.156% | Epoch Time: 12.18 secs
# Validation loss decreased (2.177665 --> 2.176227).  Saving model ...
# Epoch: 76 | Train Loss: 2.1450 | Training accuracy: 21.982% | Validation Loss: 2.177 | Validation accuracy: 20.435% | Epoch Time: 12.07 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 77 | Train Loss: 2.1450 | Training accuracy: 21.849% | Validation Loss: 2.176 | Validation accuracy: 20.498% | Epoch Time: 12.08 secs
# Validation loss decreased (2.176227 --> 2.175912).  Saving model ...
# Epoch: 78 | Train Loss: 2.1436 | Training accuracy: 22.102% | Validation Loss: 2.177 | Validation accuracy: 20.197% | Epoch Time: 12.08 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 79 | Train Loss: 2.1426 | Training accuracy: 22.185% | Validation Loss: 2.177 | Validation accuracy: 20.290% | Epoch Time: 12.08 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 80 | Train Loss: 2.1435 | Training accuracy: 21.996% | Validation Loss: 2.178 | Validation accuracy: 20.259% | Epoch Time: 12.17 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 81 | Train Loss: 2.1410 | Training accuracy: 22.081% | Validation Loss: 2.176 | Validation accuracy: 20.726% | Epoch Time: 12.25 secs
# Validation loss decreased (2.175912 --> 2.175757).  Saving model ...
# Epoch: 82 | Train Loss: 2.1421 | Training accuracy: 22.017% | Validation Loss: 2.176 | Validation accuracy: 20.456% | Epoch Time: 12.06 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 83 | Train Loss: 2.1419 | Training accuracy: 22.177% | Validation Loss: 2.175 | Validation accuracy: 20.632% | Epoch Time: 12.06 secs
# Validation loss decreased (2.175757 --> 2.175314).  Saving model ...
# Epoch: 84 | Train Loss: 2.1402 | Training accuracy: 22.212% | Validation Loss: 2.178 | Validation accuracy: 20.207% | Epoch Time: 12.07 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 85 | Train Loss: 2.1397 | Training accuracy: 22.179% | Validation Loss: 2.179 | Validation accuracy: 20.311% | Epoch Time: 12.06 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 86 | Train Loss: 2.1407 | Training accuracy: 22.258% | Validation Loss: 2.176 | Validation accuracy: 20.498% | Epoch Time: 12.15 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 87 | Train Loss: 2.1410 | Training accuracy: 21.893% | Validation Loss: 2.183 | Validation accuracy: 19.969% | Epoch Time: 12.20 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 88 | Train Loss: 2.1397 | Training accuracy: 22.305% | Validation Loss: 2.181 | Validation accuracy: 19.865% | Epoch Time: 12.05 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 89 | Train Loss: 2.1402 | Training accuracy: 22.086% | Validation Loss: 2.178 | Validation accuracy: 20.425% | Epoch Time: 12.07 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 90 | Train Loss: 2.1353 | Training accuracy: 22.440% | Validation Loss: 2.176 | Validation accuracy: 20.570% | Epoch Time: 12.06 secs
# EarlyStopping counter: 7 out of 10
# Epoch: 91 | Train Loss: 2.1356 | Training accuracy: 22.436% | Validation Loss: 2.175 | Validation accuracy: 20.446% | Epoch Time: 12.08 secs
# Validation loss decreased (2.175314 --> 2.175044).  Saving model ...
# Epoch: 92 | Train Loss: 2.1373 | Training accuracy: 22.428% | Validation Loss: 2.177 | Validation accuracy: 20.467% | Epoch Time: 12.11 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 93 | Train Loss: 2.1337 | Training accuracy: 22.397% | Validation Loss: 2.177 | Validation accuracy: 20.550% | Epoch Time: 12.50 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 94 | Train Loss: 2.1345 | Training accuracy: 22.409% | Validation Loss: 2.175 | Validation accuracy: 20.798% | Epoch Time: 12.11 secs
# Validation loss decreased (2.175044 --> 2.175001).  Saving model ...
# Epoch: 95 | Train Loss: 2.1326 | Training accuracy: 22.791% | Validation Loss: 2.174 | Validation accuracy: 20.581% | Epoch Time: 12.03 secs
# Validation loss decreased (2.175001 --> 2.174497).  Saving model ...
# Epoch: 96 | Train Loss: 2.1343 | Training accuracy: 22.645% | Validation Loss: 2.176 | Validation accuracy: 20.529% | Epoch Time: 12.12 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 97 | Train Loss: 2.1357 | Training accuracy: 22.577% | Validation Loss: 2.176 | Validation accuracy: 20.643% | Epoch Time: 12.06 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 98 | Train Loss: 2.1327 | Training accuracy: 22.424% | Validation Loss: 2.177 | Validation accuracy: 20.363% | Epoch Time: 12.10 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 99 | Train Loss: 2.1339 | Training accuracy: 22.484% | Validation Loss: 2.176 | Validation accuracy: 20.684% | Epoch Time: 12.30 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 100 | Train Loss: 2.1354 | Training accuracy: 22.191% | Validation Loss: 2.179 | Validation accuracy: 20.301% | Epoch Time: 12.26 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 101 | Train Loss: 2.1336 | Training accuracy: 22.438% | Validation Loss: 2.178 | Validation accuracy: 20.228% | Epoch Time: 12.12 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 102 | Train Loss: 2.1331 | Training accuracy: 22.598% | Validation Loss: 2.176 | Validation accuracy: 20.487% | Epoch Time: 12.09 secs
# EarlyStopping counter: 7 out of 10
# Epoch: 103 | Train Loss: 2.1312 | Training accuracy: 22.511% | Validation Loss: 2.174 | Validation accuracy: 20.529% | Epoch Time: 12.08 secs
# Validation loss decreased (2.174497 --> 2.174329).  Saving model ...
# Epoch: 104 | Train Loss: 2.1299 | Training accuracy: 22.948% | Validation Loss: 2.175 | Validation accuracy: 20.498% | Epoch Time: 12.07 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 105 | Train Loss: 2.1313 | Training accuracy: 22.260% | Validation Loss: 2.176 | Validation accuracy: 20.601% | Epoch Time: 12.19 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 106 | Train Loss: 2.1297 | Training accuracy: 22.782% | Validation Loss: 2.175 | Validation accuracy: 20.581% | Epoch Time: 12.14 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 107 | Train Loss: 2.1317 | Training accuracy: 22.448% | Validation Loss: 2.175 | Validation accuracy: 20.394% | Epoch Time: 12.07 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 108 | Train Loss: 2.1311 | Training accuracy: 22.594% | Validation Loss: 2.175 | Validation accuracy: 20.290% | Epoch Time: 12.09 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 109 | Train Loss: 2.1298 | Training accuracy: 22.455% | Validation Loss: 2.175 | Validation accuracy: 20.508% | Epoch Time: 12.08 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 110 | Train Loss: 2.1281 | Training accuracy: 22.830% | Validation Loss: 2.174 | Validation accuracy: 20.529% | Epoch Time: 12.13 secs
# EarlyStopping counter: 7 out of 10
# Epoch: 111 | Train Loss: 2.1293 | Training accuracy: 22.714% | Validation Loss: 2.175 | Validation accuracy: 20.394% | Epoch Time: 12.18 secs
# EarlyStopping counter: 8 out of 10
# Epoch: 112 | Train Loss: 2.1277 | Training accuracy: 22.594% | Validation Loss: 2.176 | Validation accuracy: 20.363% | Epoch Time: 12.14 secs
# EarlyStopping counter: 9 out of 10
# Epoch: 113 | Train Loss: 2.1300 | Training accuracy: 22.755% | Validation Loss: 2.175 | Validation accuracy: 20.550% | Epoch Time: 12.05 secs
# EarlyStopping counter: 10 out of 10
# ==> Finished Training ...
# test accuracy: 20.759%

# %% [markdown]
# # Compile with Optuna

# %%
# !pip install optuna
import optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.0)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 28.4 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 22.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.3.0

# %%
def compile_model(trial):
    # hyper-parameters
    epochs = 200
    learning_rate = trial.suggest_float("learning_rate", 1e-2, 1e-1, log=True) # log=True, will use log scale
    weight_decay = trial.suggest_float("weight_decay", 1e-5, 1e-3, log=True) # log=True, will use log scale
    batch_size = trial.suggest_int("batch_size", 64, 256) # batch_size will be between 64 and 256

    # Generate the model
    model = CNN(
        num_channel = 14,
        num_classes = 10,
        signal_length = 224,
        kernel_window_eeg = 32,
        filters_n1 = 8,
    ).to(device)

    # load data
    train_loader, valid_loader, test_loader = GetDataLoaders(x, y, batch_size=batch_size)

    # loss criterion
    criterion = nn.CrossEntropyLoss()

    # optimizer - SGD, Adam, RMSProp...
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=learning_rate,
                                               weight_decay=weight_decay)

    # Learning Rate Scheduler
    scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=50,
                                  verbose=True)

    # Early Stopping
    early_stopping = EarlyStopping(delta=0.00, patience=10, verbose=True)

    # training loop
    train_losses = []
    valid_losses = []
    for epoch in range(1, epochs + 1):
        model.train() # put in training mode
        running_loss = 0.0
        total_correct = 0
        total_images = 0
        epoch_time = time.time()
        for train_data in train_loader:
            # get the inputs
            inputs, labels = train_data
            # send them to device
            inputs = inputs.to(device)
            labels = labels.to(device)

            # forward + backward + optimize
            outputs = model(inputs) # forward pass
            loss = criterion(outputs, labels) # calculate the loss

            # always the same 3 steps
            loss.backward() # backpropagation
            optimizer.step() # update parameters
            optimizer.zero_grad() # zero the parameter gradients

            # calc accuracy
            _, predicted = torch.max(outputs.data, 1)
            total_images += labels.size(0)
            total_correct += (predicted == labels).sum().item()

            # print statistics
            running_loss += loss.data.item()

        # Normalizing the loss by the total number of train batches
        running_loss /= len(train_loader)
        train_losses.append(running_loss)

        # Calculate training and validation set accuracy of the existing model
        train_accuracy = total_correct / total_images * 100
        valid_accuracy, _, valid_loss = calculate_accuracy(model, valid_loader, device, criterion)
        valid_losses.append(valid_loss)

        log = "Epoch: {} | Train Loss: {:.4f} | Training accuracy: {:.3f}% | Validation Loss: {:.3f} | Validation accuracy: {:.3f}% | ".format(epoch
        , running_loss, train_accuracy, valid_loss, valid_accuracy)
        epoch_time = time.time() - epoch_time
        log += "Epoch Time: {:.2f} secs".format(epoch_time)
        print(log)

        # accuracy is used to track down a plateau
        scheduler.step(valid_accuracy)

        # Early Stopping
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            break

        # report back to Optuna how far it is (epoch-wise) into the trial and how
        # well it is doing (validation accuracy)
        trial.report(valid_accuracy, epoch)

        # then, Optuna can decide if the trial should be pruned
        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    print('==> Finished Training ...')

    # print loss curves
    plt.plot(train_losses, label='Train Loss')
    plt.plot(valid_losses, label='Validation Loss')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss')

    # calculate accuracy and confusion matrix
    test_accuracy, confusion_matrix, _ = calculate_accuracy(model, test_loader, device, criterion)
    print("test accuracy: {:.3f}%".format(test_accuracy))

    # plot confusion matrix
    fig, ax = plt.subplots(1,1,figsize=(8,6))
    ax.matshow(confusion_matrix, aspect='auto', vmin=0, vmax=1000, cmap=plt.get_cmap('Blues'))
    plt.ylabel('Actual Category')
    plt.yticks(range(10), range(10))
    plt.xlabel('Predicted Category')
    plt.xticks(range(10), range(10))
    plt.show()

    return valid_accuracy

# %%
# Compile with Optuna
sampler = optuna.samplers.TPESampler()
study = optuna.create_study(study_name="EEG-CNN", direction="maximize", sampler=sampler)
study.optimize(compile_model, n_trials=2)
pruned_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.PRUNED]
complete_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
print("Study statistics: ")
print(" Number of finished trials: ", len(study.trials))
print(" Number of pruned trials: ", len(pruned_trials))
print(" Number of complete trials: ", len(complete_trials))
print("Best trial:")
trial = study.best_trial
print(" Value: ", trial.value)
print(" Params: ")
for key, value in trial.params.items():
 print(" {}: {}".format(key, value))
# Out:
# [I 2025-04-23 05:02:49,788] A new study created in memory with name: EEG-CNN
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch: 1 | Train Loss: 14.1868 | Training accuracy: 10.202% | Validation Loss: 2.304 | Validation accuracy: 10.171% | Epoch Time: 13.09 secs
# Validation loss decreased (inf --> 2.303917).  Saving model ...
# Epoch: 2 | Train Loss: 2.3091 | Training accuracy: 9.984% | Validation Loss: 2.305 | Validation accuracy: 9.943% | Epoch Time: 12.25 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 3 | Train Loss: 5.0861 | Training accuracy: 9.964% | Validation Loss: 2.305 | Validation accuracy: 10.026% | Epoch Time: 12.32 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 4 | Train Loss: 2.4439 | Training accuracy: 9.924% | Validation Loss: 2.308 | Validation accuracy: 9.974% | Epoch Time: 12.67 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 5 | Train Loss: 6.1921 | Training accuracy: 10.022% | Validation Loss: 2.304 | Validation accuracy: 9.943% | Epoch Time: 12.07 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 6 | Train Loss: 2.3070 | Training accuracy: 9.993% | Validation Loss: 2.305 | Validation accuracy: 10.202% | Epoch Time: 12.08 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 7 | Train Loss: 3.2713 | Training accuracy: 9.990% | Validation Loss: 2.306 | Validation accuracy: 10.109% | Epoch Time: 12.13 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 8 | Train Loss: 2.9413 | Training accuracy: 9.908% | Validation Loss: 2.304 | Validation accuracy: 9.974% | Epoch Time: 12.06 secs
# EarlyStopping counter: 7 out of 10
# Epoch: 9 | Train Loss: 3.1275 | Training accuracy: 9.997% | Validation Loss: 2.309 | Validation accuracy: 9.974% | Epoch Time: 12.10 secs
# EarlyStopping counter: 8 out of 10
# Epoch: 10 | Train Loss: 3.2130 | Training accuracy: 10.192% | Validation Loss: 2.309 | Validation accuracy: 10.171% | Epoch Time: 12.17 secs
# EarlyStopping counter: 9 out of 10
# Epoch: 11 | Train Loss: 4.0310 | Training accuracy: 10.007% | Validation Loss: 2.305 | Validation accuracy: 10.005% | Epoch Time: 12.14 secs
# EarlyStopping counter: 10 out of 10
# ==> Finished Training ...
# test accuracy: 10.403%
# [I 2025-04-23 05:05:08,050] Trial 0 finished with value: 10.005184033177812 and parameters: {'learning_rate': 0.04667478836283911, 'weight_decay': 1.4394510511691997e-05, 'batch_size': 124, 'optimizer': 'RMSprop'}. Best is trial 0 with value: 10.005184033177812.
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch: 1 | Train Loss: 12.7294 | Training accuracy: 10.185% | Validation Loss: 2.310 | Validation accuracy: 10.347% | Epoch Time: 12.67 secs
# Validation loss decreased (inf --> 2.309893).  Saving model ...
# Epoch: 2 | Train Loss: 3.3153 | Training accuracy: 10.127% | Validation Loss: 2.306 | Validation accuracy: 10.420% | Epoch Time: 12.61 secs
# Validation loss decreased (2.309893 --> 2.305652).  Saving model ...
# Epoch: 3 | Train Loss: 6.0971 | Training accuracy: 10.061% | Validation Loss: 2.315 | Validation accuracy: 9.725% | Epoch Time: 12.54 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 4 | Train Loss: 5.9629 | Training accuracy: 9.957% | Validation Loss: 2.326 | Validation accuracy: 9.725% | Epoch Time: 12.67 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 5 | Train Loss: 2.8743 | Training accuracy: 10.158% | Validation Loss: 2.333 | Validation accuracy: 10.368% | Epoch Time: 12.56 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 6 | Train Loss: 7.1780 | Training accuracy: 10.138% | Validation Loss: 2.317 | Validation accuracy: 10.420% | Epoch Time: 12.69 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 7 | Train Loss: 4.1290 | Training accuracy: 9.891% | Validation Loss: 2.308 | Validation accuracy: 10.233% | Epoch Time: 12.83 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 8 | Train Loss: 7.1237 | Training accuracy: 10.109% | Validation Loss: 2.311 | Validation accuracy: 9.974% | Epoch Time: 12.88 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 9 | Train Loss: 2.6469 | Training accuracy: 9.974% | Validation Loss: 2.315 | Validation accuracy: 9.622% | Epoch Time: 12.67 secs
# EarlyStopping counter: 7 out of 10
# Epoch: 10 | Train Loss: 6.1376 | Training accuracy: 9.914% | Validation Loss: 2.311 | Validation accuracy: 9.528% | Epoch Time: 12.95 secs
# EarlyStopping counter: 8 out of 10
# Epoch: 11 | Train Loss: 5.2120 | Training accuracy: 10.105% | Validation Loss: 2.319 | Validation accuracy: 10.347% | Epoch Time: 12.78 secs
# EarlyStopping counter: 9 out of 10
# Epoch: 12 | Train Loss: 2.7493 | Training accuracy: 9.910% | Validation Loss: 34.830 | Validation accuracy: 9.528% | Epoch Time: 12.80 secs
# EarlyStopping counter: 10 out of 10
# ==> Finished Training ...
# test accuracy: 9.858%
# [I 2025-04-23 05:07:42,416] Trial 1 finished with value: 9.528252980819078 and parameters: {'learning_rate': 0.06863611720507687, 'weight_decay': 1.7211555382391384e-05, 'batch_size': 85, 'optimizer': 'RMSprop'}. Best is trial 0 with value: 10.005184033177812.
# Study statistics:
#  Number of finished trials:  2
#  Number of pruned trials:  0
#  Number of complete trials:  2
# Best trial:
#  Value:  10.005184033177812
#  Params:
#  learning_rate: 0.04667478836283911
#  weight_decay: 1.4394510511691997e-05
#  batch_size: 124
#  optimizer: RMSprop

# %%
 optuna.visualization.plot_param_importances(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5ee320e4-0932-42e3-8745-22521a5ca3d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ee320e4-0932-42e3-8745-22521a5ca3d6")) {                    Plotly.newPlot(                        "5ee320e4-0932-42e3-8745-22521a5ca3d6",                        [{"cliponaxis":false,"hovertemplate":["batch_size (IntDistribution): 0.0\u003cextra\u003e\u003c\u002fextra\u003e","optimizer (CategoricalDistribution): 0.0\u003cextra\u003e\u003c\u002fextra\u003e","weight_decay (FloatDistribution): 0.46875\u003cextra\u003e\u003c\u002fextra\u003e","learning_rate (FloatDistribution): 0.53125\u003cextra\u003e\u003c\u002fextra\u003e"],"name":"Objective Value","orientation":"h","text":["\u003c0.01","\u003c0.01","0.47","0.53"],"textposition":"outside","x":[0.0,0.0,0.46875,0.53125],"y":["batch_size","optimizer","weight_decay","learning_rate"],"type":"bar"}],                        {"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Hyperparameter Importance"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpo ...
