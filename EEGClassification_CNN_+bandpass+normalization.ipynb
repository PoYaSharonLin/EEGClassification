# %%
import numpy as np
import numpy.fft as fft
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import signal
import sklearn
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torchvision
import torchaudio
from torchvision import transforms
import cv2
# %matplotlib inline
from utils import MindBigData, GetDataSet, GetDataLoaders, GetDataLoadersEEGImages, GetDataAndPreProcess, preprocess_signal
import time


seed = 123
np.random.seed(seed)
torch.manual_seed(seed)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Uninstall the pre-installed NumPy (optional)
# !pip uninstall -y numpy

# !pip install numpy==2.0.0
# !pip install scipy>=1.14

import numpy as np
print(np.__version__)
# Out:
# Found existing installation: numpy 2.0.0
# Uninstalling numpy-2.0.0:
#   Successfully uninstalled numpy-2.0.0
# Collecting numpy==2.0.0
#   Using cached numpy-2.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Using cached numpy-2.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.0.0
# 2.0.0

# %%
# download dataset to google drive
# def DownloadDataSet(link, drive_path, colab_path, filename):
    #! wget -c -P "{drive_path}" "{link}"
    #!unzip "{drive_path}/{filename}" -d "{drive_path}"
    #!cp -r "{drive_path}" "{colab_path}"

# %%
#link = 'http://www.mindbigdata.com/opendb/MindBigData-EP-v1.0.zip'
#drive_path = '/content/drive/MyDrive/113-2/BCI/data'
#colab_path = '.'

#DownloadDataSet(link, drive_path, colab_path,"MindBigData-EP-v1.0.zip")

# %%
x, y = GetDataAndPreProcess(input_file="/content/drive/MyDrive/113-2/BCI/EP1.01.txt", samples_per_digit=6500)
# Out:
# [6466, 6324, 6443, 6500, 6304, 6500, 6478, 6293, 6494, 6500]

# %%
train_loader, valid_loader, test_loader = GetDataLoaders(x, y, batch_size=64)

# %% [markdown]
# ## Plot

# %%
def plot_signal_comparison(signal_original, fs=128, lowcut=0.5, highcut=50, order=4):
    """
    Plots original, filtered, and normalized EEG signals with their PSDs.

    Parameters:
    - signal_original: 1D array, the original EEG signal.
    - fs: float, sampling frequency in Hz (default: 128 Hz).
    - lowcut: float, low cutoff frequency in Hz (default: 0.5 Hz).
    - highcut: float, high cutoff frequency in Hz (default: 50 Hz).
    - order: int, order of the Butterworth filter (default: 4).
    """
    # Apply preprocessing
    signal_filtered, signal_normalized = preprocess_signal(signal_original, fs, lowcut, highcut, order)

    # Time domain plots
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.plot(signal_original)
    plt.title('Original Signal')
    plt.xlabel('Time (samples)')
    plt.ylabel('Amplitude')

    plt.subplot(1, 3, 2)
    plt.plot(signal_filtered)
    plt.title('Filtered Signal (0.5-50 Hz)')
    plt.xlabel('Time (samples)')
    plt.ylabel('Amplitude')

    plt.subplot(1, 3, 3)
    plt.plot(signal_normalized)
    plt.title('Normalized Signal')
    plt.xlabel('Time (samples)')
    plt.ylabel('Amplitude (z-score)')

    plt.tight_layout()
    plt.savefig('signal_comparison_time.png')

    # Frequency domain (PSD)
    f_original, Pxx_original = signal.welch(signal_original, fs=fs, nperseg=256)
    f_filtered, Pxx_filtered = signal.welch(signal_filtered, fs=fs, nperseg=256)

    plt.figure(figsize=(10, 5))
    plt.semilogy(f_original, Pxx_original, label='Original')
    plt.semilogy(f_filtered, Pxx_filtered, label='Filtered')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Power Spectral Density (V²/Hz)')
    plt.title('PSD Comparison')
    plt.legend()
    plt.grid(True)
    plt.savefig('signal_comparison_psd.png')

# %%
plot_signal_comparison(x[0, 0])
# Out:
# /usr/local/lib/python3.11/dist-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 256 is greater than input length  = 224, using nperseg = 224
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,

# %%
# Display 2 signals with their labels
# replace .next() with next() in Python3
data_iter = iter(train_loader)
inputs, labels = next(data_iter)
EEGChannel = ["AF3", "F7", "F3", "FC5", "T7", "P7", "O1", "O2", "P8", "T8", "FC6", "F4", "F8", "AF4"]

fig = plt.figure(figsize=(20, 15))
fig.suptitle('EEG signals', fontsize=16)
for i in range(2):
    for j in range(14):
        ax = fig.add_subplot(14, 2, i + 1 + 2 * j)
        if (j == 0):
            ax.set_title(
                'digit seen by patient: ' + str(labels[i].item()))  # .item() gets the value contained in a tensor
        ax.plot(inputs[i][j])
        ax.set_xlabel('samples')
        ax.set_ylabel(EEGChannel[j])
        ax.grid()

# %%
# Display 2 FFT of signals with their labels
f = np.arange(-112, 112) * 0.5
fig = plt.figure(figsize=(20, 15))
fig.suptitle('FFT of EEG signals', fontsize=16)
for i in range(2):
    for j in range(14):
        ax = fig.add_subplot(14, 2, i + 1 + 2 * j)
        if (j == 0):
            ax.set_title(
                'digit seen by patient: ' + str(labels[i].item()))  # .item() gets the value contained in a tensor
        ax.plot(f, abs(fft.fftshift(fft.fft(inputs[i][j]))))
        ax.set_xlabel('frequencies')
        ax.set_ylabel(EEGChannel[j])
        ax.grid()

# %%
class CNN(nn.Module):
    def __init__(self, num_channel=10, num_classes=4, signal_length=1000,
                 filters_n1=4, kernel_window_eeg=39, kernel_window=19,
                 conv_3_dilation=4, conv_4_dilation=4):
        super().__init__()

        filters = [filters_n1, filters_n1 * 2]

        self.conv_1 = Conv2dBlockELU(in_ch=1, out_ch=filters[0], kernel_size=(1, kernel_window_eeg), w_in=signal_length)

        self.conv_1_1 = Conv2dBlockELU(in_ch=filters[0], out_ch=filters[0], kernel_size=(1, kernel_window_eeg), w_in=self.conv_1.w_out)

        self.conv_2 = Conv2dBlockELU(in_ch=filters[0], out_ch=filters[0], kernel_size=(num_channel, 1))

        self.conv_3 = Conv2dBlockELU(in_ch=filters[0], out_ch=filters[1], kernel_size=(1, kernel_window),
                                     padding=(0,conv_3_dilation-1), dilation=(1,conv_3_dilation), w_in=self.conv_1.w_out)

        self.conv_4 = Conv2dBlockELU(in_ch=filters[1], out_ch=filters[1], kernel_size=(1, kernel_window),
                                     padding=(0,conv_4_dilation-1), dilation=(1,conv_4_dilation), w_in=self.conv_3.w_out)

        self.fc_layer = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(480, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 10),
        )

        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = torch.unsqueeze(x, 1)

        # conv layers
        x = self.conv_1(x)
        x = self.conv_1_1(x)
        x = self.conv_2(x)
        x = self.dropout(x)
        x = self.conv_3(x)
        x = self.conv_4(x)
        x = self.dropout(x)

        # flatten
        x = x.view(x.size(0), -1)

        # fc layers
        x = self.fc_layer(x)

        return x


class Conv2dBlockELU(nn.Module):
    def __init__(self, in_ch, out_ch, kernel_size, padding=(0,0), dilation=(1,1), groups=1, w_in=None):
        super(Conv2dBlockELU, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=kernel_size, padding=padding, dilation=dilation, groups=groups),
            nn.BatchNorm2d(out_ch),
            nn.ELU(inplace=True)
        )

        if w_in is not None:
            self.w_out = int( ((w_in + 2 * padding[1] - dilation[1] * (kernel_size[1]-1)-1) / 1) + 1 )

        self.out_ch = out_ch

    def forward(self, x):
        return self.conv(x)

# %%
model = CNN(
        num_channel = 14,
        num_classes = 10,
        signal_length = 224,
        kernel_window_eeg = 32,
        filters_n1 = 8,
    ).to(device)
print("Model Architecture:")
print(model)
# Out:
# Model Architecture:
# CNN(
#   (conv_1): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(1, 8, kernel_size=(1, 32), stride=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (conv_1_1): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(8, 8, kernel_size=(1, 32), stride=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (conv_2): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(8, 8, kernel_size=(14, 1), stride=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (conv_3): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(8, 16, kernel_size=(1, 19), stride=(1, 1), padding=(0, 3), dilation=(1, 4))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (conv_4): Conv2dBlockELU(
#     (conv): Sequential(
#       (0): Conv2d(16, 16, kernel_size=(1, 19), stride=(1, 1), padding=(0, 3), dilation=(1, 4))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0, inplace=True)
#     )
#   )
#   (fc_layer): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=480, out_features=256, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
### Helper Functions ###
# function to calcualte accuracy of the model
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement.
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

def calculate_accuracy(model, dataloader, device, criterion):
    model.eval() # put in evaluation mode
    total_correct = 0
    total_images = 0
    running_loss = 0.0
    confusion_matrix = np.zeros([10,10], int)
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images = images.float()
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels) # calculate the loss
            running_loss += loss.data.item()
            _, predicted = torch.max(outputs.data, 1)
            total_images += labels.size(0)
            total_correct += (predicted == labels).sum().item()
            for i, l in enumerate(labels):
                confusion_matrix[l.item(), predicted[i].item()] += 1

    # Normalizing the loss by the total number of train batches
    running_loss /= len(dataloader)
    model_accuracy = total_correct / total_images * 100
    return model_accuracy, confusion_matrix, running_loss

# use a different initialization for the model
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Linear') != -1:
        nn.init.normal_(m.bias, 0, 0.005)
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

# %%
def compile_model(model):
    # hyper-parameters
    learning_rate = 0.06
    epochs = 200
    weight_decay = 9e-4
    batch_size = 215

    # get data loaders
    train_loader, valid_loader, test_loader = GetDataLoaders(x, y, batch_size)

    # loss criterion
    criterion = nn.CrossEntropyLoss()

    # optimizer - SGD, Adam, RMSProp...
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,
                                    weight_decay=weight_decay)

    # Learning Rate Scheduler
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5,
                                  verbose=True)

    # Early Stopping
    early_stopping = EarlyStopping(delta=0.00, patience=10, verbose=True)

    # training loop
    train_losses = []
    valid_losses = []
    for epoch in range(1, epochs + 1):
        model.train() # put in training mode
        running_loss = 0.0
        total_correct = 0
        total_images = 0
        epoch_time = time.time()
        for train_data in train_loader:
            # get the inputs
            inputs, labels = train_data
            # send them to device
            inputs = inputs.to(device)
            labels = labels.to(device)

            # forward + backward + optimize
            outputs = model(inputs) # forward pass
            loss = criterion(outputs, labels) # calculate the loss

            # always the same 3 steps
            loss.backward() # backpropagation
            optimizer.step() # update parameters
            optimizer.zero_grad() # zero the parameter gradients

            # calc accuracy
            _, predicted = torch.max(outputs.data, 1)
            total_images += labels.size(0)
            total_correct += (predicted == labels).sum().item()

            # print statistics
            running_loss += loss.data.item()

        # Normalizing the loss by the total number of train batches
        running_loss /= len(train_loader)
        train_losses.append(running_loss)

        # Calculate training/test set accuracy of the existing model
        train_accuracy = total_correct / total_images * 100
        valid_accuracy, _, valid_loss = calculate_accuracy(model, valid_loader, device, criterion)
        valid_losses.append(valid_loss)

        log = "Epoch: {} | Train Loss: {:.4f} | Training accuracy: {:.3f}% | Validation Loss: {:.3f} | Validation accuracy: {:.3f}% | ".format(epoch
        , running_loss, train_accuracy, valid_loss, valid_accuracy)
        epoch_time = time.time() - epoch_time
        log += "Epoch Time: {:.2f} secs".format(epoch_time)
        print(log)

        # accuracy is used to track down a plateau
        scheduler.step(valid_loss)

        # Early Stopping
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            break

    print('==> Finished Training ...')

    # calculate accuracy and confusion matrix
    test_accuracy, confusion_matrix, _ = calculate_accuracy(model, test_loader, device, criterion)
    print("test accuracy: {:.3f}%".format(test_accuracy))

    # plot confusion matrix
    fig, ax = plt.subplots(1,1,figsize=(8,6))
    ax.matshow(confusion_matrix, aspect='auto', vmin=0, vmax=1000, cmap=plt.get_cmap('Blues'))
    plt.ylabel('Actual Category')
    plt.yticks(range(10), range(10))
    plt.xlabel('Predicted Category')
    plt.xticks(range(10), range(10))
    plt.show()

    # print loss curves
    plt.plot(train_losses, label='Train Loss')
    plt.plot(valid_losses, label='Validation Loss')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss')

# %%
model = CNN(
        num_channel = 14,
        num_classes = 10,
        signal_length = 224,
        kernel_window_eeg = 32,
        filters_n1 = 8,
    ).to(device)
compile_model(model=model)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch: 1 | Train Loss: 2.3219 | Training accuracy: 10.202% | Validation Loss: 2.300 | Validation accuracy: 11.664% | Epoch Time: 12.61 secs
# Validation loss decreased (inf --> 2.299507).  Saving model ...
# Epoch: 2 | Train Loss: 2.3014 | Training accuracy: 11.529% | Validation Loss: 2.288 | Validation accuracy: 12.722% | Epoch Time: 11.04 secs
# Validation loss decreased (2.299507 --> 2.288035).  Saving model ...
# Epoch: 3 | Train Loss: 2.2910 | Training accuracy: 12.769% | Validation Loss: 2.281 | Validation accuracy: 13.209% | Epoch Time: 11.21 secs
# Validation loss decreased (2.288035 --> 2.280551).  Saving model ...
# Epoch: 4 | Train Loss: 2.2849 | Training accuracy: 13.416% | Validation Loss: 2.278 | Validation accuracy: 13.375% | Epoch Time: 11.29 secs
# Validation loss decreased (2.280551 --> 2.278336).  Saving model ...
# Epoch: 5 | Train Loss: 2.2802 | Training accuracy: 13.729% | Validation Loss: 2.274 | Validation accuracy: 14.142% | Epoch Time: 11.48 secs
# Validation loss decreased (2.278336 --> 2.274157).  Saving model ...
# Epoch: 6 | Train Loss: 2.2760 | Training accuracy: 14.019% | Validation Loss: 2.272 | Validation accuracy: 13.997% | Epoch Time: 11.47 secs
# Validation loss decreased (2.274157 --> 2.272155).  Saving model ...
# Epoch: 7 | Train Loss: 2.2730 | Training accuracy: 14.295% | Validation Loss: 2.271 | Validation accuracy: 13.665% | Epoch Time: 11.55 secs
# Validation loss decreased (2.272155 --> 2.271113).  Saving model ...
# Epoch: 8 | Train Loss: 2.2690 | Training accuracy: 14.747% | Validation Loss: 2.266 | Validation accuracy: 14.806% | Epoch Time: 11.65 secs
# Validation loss decreased (2.271113 --> 2.265652).  Saving model ...
# Epoch: 9 | Train Loss: 2.2638 | Training accuracy: 14.880% | Validation Loss: 2.262 | Validation accuracy: 15.480% | Epoch Time: 12.05 secs
# Validation loss decreased (2.265652 --> 2.261738).  Saving model ...
# Epoch: 10 | Train Loss: 2.2597 | Training accuracy: 15.338% | Validation Loss: 2.262 | Validation accuracy: 15.635% | Epoch Time: 11.87 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 11 | Train Loss: 2.2553 | Training accuracy: 15.664% | Validation Loss: 2.254 | Validation accuracy: 15.677% | Epoch Time: 11.86 secs
# Validation loss decreased (2.261738 --> 2.254343).  Saving model ...
# Epoch: 12 | Train Loss: 2.2525 | Training accuracy: 15.807% | Validation Loss: 2.250 | Validation accuracy: 16.153% | Epoch Time: 11.88 secs
# Validation loss decreased (2.254343 --> 2.249670).  Saving model ...
# Epoch: 13 | Train Loss: 2.2485 | Training accuracy: 16.188% | Validation Loss: 2.252 | Validation accuracy: 15.666% | Epoch Time: 11.80 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 14 | Train Loss: 2.2458 | Training accuracy: 16.487% | Validation Loss: 2.250 | Validation accuracy: 15.946% | Epoch Time: 11.71 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 15 | Train Loss: 2.2445 | Training accuracy: 16.547% | Validation Loss: 2.243 | Validation accuracy: 16.796% | Epoch Time: 11.71 secs
# Validation loss decreased (2.249670 --> 2.242802).  Saving model ...
# Epoch: 16 | Train Loss: 2.2403 | Training accuracy: 16.663% | Validation Loss: 2.239 | Validation accuracy: 16.682% | Epoch Time: 11.76 secs
# Validation loss decreased (2.242802 --> 2.239336).  Saving model ...
# Epoch: 17 | Train Loss: 2.2367 | Training accuracy: 17.068% | Validation Loss: 2.245 | Validation accuracy: 16.340% | Epoch Time: 11.80 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 18 | Train Loss: 2.2350 | Training accuracy: 17.072% | Validation Loss: 2.235 | Validation accuracy: 17.367% | Epoch Time: 11.79 secs
# Validation loss decreased (2.239336 --> 2.234903).  Saving model ...
# Epoch: 19 | Train Loss: 2.2309 | Training accuracy: 17.331% | Validation Loss: 2.231 | Validation accuracy: 17.159% | Epoch Time: 11.80 secs
# Validation loss decreased (2.234903 --> 2.230651).  Saving model ...
# Epoch: 20 | Train Loss: 2.2275 | Training accuracy: 17.414% | Validation Loss: 2.236 | Validation accuracy: 16.682% | Epoch Time: 12.04 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 21 | Train Loss: 2.2253 | Training accuracy: 17.528% | Validation Loss: 2.228 | Validation accuracy: 17.367% | Epoch Time: 11.78 secs
# Validation loss decreased (2.230651 --> 2.228277).  Saving model ...
# Epoch: 22 | Train Loss: 2.2233 | Training accuracy: 17.671% | Validation Loss: 2.228 | Validation accuracy: 17.211% | Epoch Time: 11.91 secs
# Validation loss decreased (2.228277 --> 2.227569).  Saving model ...
# Epoch: 23 | Train Loss: 2.2219 | Training accuracy: 17.797% | Validation Loss: 2.224 | Validation accuracy: 17.646% | Epoch Time: 11.88 secs
# Validation loss decreased (2.227569 --> 2.224206).  Saving model ...
# Epoch: 24 | Train Loss: 2.2191 | Training accuracy: 18.113% | Validation Loss: 2.220 | Validation accuracy: 18.072% | Epoch Time: 11.88 secs
# Validation loss decreased (2.224206 --> 2.220237).  Saving model ...
# Epoch: 25 | Train Loss: 2.2162 | Training accuracy: 17.967% | Validation Loss: 2.220 | Validation accuracy: 17.947% | Epoch Time: 11.69 secs
# Validation loss decreased (2.220237 --> 2.220157).  Saving model ...
# Epoch: 26 | Train Loss: 2.2143 | Training accuracy: 18.142% | Validation Loss: 2.214 | Validation accuracy: 18.227% | Epoch Time: 11.66 secs
# Validation loss decreased (2.220157 --> 2.213502).  Saving model ...
# Epoch: 27 | Train Loss: 2.2111 | Training accuracy: 18.484% | Validation Loss: 2.207 | Validation accuracy: 18.922% | Epoch Time: 11.69 secs
# Validation loss decreased (2.213502 --> 2.207462).  Saving model ...
# Epoch: 28 | Train Loss: 2.2100 | Training accuracy: 18.527% | Validation Loss: 2.206 | Validation accuracy: 18.756% | Epoch Time: 11.72 secs
# Validation loss decreased (2.207462 --> 2.205912).  Saving model ...
# Epoch: 29 | Train Loss: 2.2069 | Training accuracy: 18.473% | Validation Loss: 2.208 | Validation accuracy: 18.942% | Epoch Time: 11.68 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 30 | Train Loss: 2.2038 | Training accuracy: 18.749% | Validation Loss: 2.214 | Validation accuracy: 18.932% | Epoch Time: 11.65 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 31 | Train Loss: 2.2000 | Training accuracy: 18.880% | Validation Loss: 2.210 | Validation accuracy: 18.092% | Epoch Time: 11.63 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 32 | Train Loss: 2.1992 | Training accuracy: 19.037% | Validation Loss: 2.209 | Validation accuracy: 18.787% | Epoch Time: 11.76 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 33 | Train Loss: 2.1980 | Training accuracy: 19.178% | Validation Loss: 2.199 | Validation accuracy: 18.922% | Epoch Time: 11.74 secs
# Validation loss decreased (2.205912 --> 2.198718).  Saving model ...
# Epoch: 34 | Train Loss: 2.1970 | Training accuracy: 19.270% | Validation Loss: 2.197 | Validation accuracy: 19.005% | Epoch Time: 11.68 secs
# Validation loss decreased (2.198718 --> 2.196695).  Saving model ...
# Epoch: 35 | Train Loss: 2.1948 | Training accuracy: 19.322% | Validation Loss: 2.203 | Validation accuracy: 18.777% | Epoch Time: 11.60 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 36 | Train Loss: 2.1910 | Training accuracy: 19.429% | Validation Loss: 2.195 | Validation accuracy: 19.523% | Epoch Time: 11.61 secs
# Validation loss decreased (2.196695 --> 2.195121).  Saving model ...
# Epoch: 37 | Train Loss: 2.1906 | Training accuracy: 19.566% | Validation Loss: 2.200 | Validation accuracy: 19.005% | Epoch Time: 11.60 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 38 | Train Loss: 2.1896 | Training accuracy: 19.336% | Validation Loss: 2.191 | Validation accuracy: 18.860% | Epoch Time: 11.61 secs
# Validation loss decreased (2.195121 --> 2.191135).  Saving model ...
# Epoch: 39 | Train Loss: 2.1889 | Training accuracy: 19.790% | Validation Loss: 2.195 | Validation accuracy: 19.171% | Epoch Time: 11.62 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 40 | Train Loss: 2.1887 | Training accuracy: 19.684% | Validation Loss: 2.194 | Validation accuracy: 19.575% | Epoch Time: 11.63 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 41 | Train Loss: 2.1864 | Training accuracy: 19.628% | Validation Loss: 2.188 | Validation accuracy: 19.274% | Epoch Time: 11.63 secs
# Validation loss decreased (2.191135 --> 2.188389).  Saving model ...
# Epoch: 42 | Train Loss: 2.1844 | Training accuracy: 19.622% | Validation Loss: 2.189 | Validation accuracy: 19.782% | Epoch Time: 11.72 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 43 | Train Loss: 2.1845 | Training accuracy: 19.599% | Validation Loss: 2.184 | Validation accuracy: 20.062% | Epoch Time: 11.73 secs
# Validation loss decreased (2.188389 --> 2.183720).  Saving model ...
# Epoch: 44 | Train Loss: 2.1848 | Training accuracy: 19.850% | Validation Loss: 2.185 | Validation accuracy: 19.896% | Epoch Time: 11.85 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 45 | Train Loss: 2.1824 | Training accuracy: 19.821% | Validation Loss: 2.187 | Validation accuracy: 19.658% | Epoch Time: 11.66 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 46 | Train Loss: 2.1821 | Training accuracy: 19.890% | Validation Loss: 2.187 | Validation accuracy: 19.824% | Epoch Time: 11.61 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 47 | Train Loss: 2.1787 | Training accuracy: 19.998% | Validation Loss: 2.185 | Validation accuracy: 19.316% | Epoch Time: 11.61 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 48 | Train Loss: 2.1819 | Training accuracy: 20.062% | Validation Loss: 2.183 | Validation accuracy: 19.948% | Epoch Time: 11.66 secs
# Validation loss decreased (2.183720 --> 2.182677).  Saving model ...
# Epoch: 49 | Train Loss: 2.1791 | Training accuracy: 20.097% | Validation Loss: 2.187 | Validation accuracy: 19.440% | Epoch Time: 11.64 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 50 | Train Loss: 2.1768 | Training accuracy: 19.977% | Validation Loss: 2.184 | Validation accuracy: 20.166% | Epoch Time: 11.65 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 51 | Train Loss: 2.1762 | Training accuracy: 20.062% | Validation Loss: 2.180 | Validation accuracy: 19.762% | Epoch Time: 11.76 secs
# Validation loss decreased (2.182677 --> 2.180406).  Saving model ...
# Epoch: 52 | Train Loss: 2.1771 | Training accuracy: 20.404% | Validation Loss: 2.199 | Validation accuracy: 19.492% | Epoch Time: 11.78 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 53 | Train Loss: 2.1745 | Training accuracy: 20.132% | Validation Loss: 2.182 | Validation accuracy: 19.647% | Epoch Time: 11.84 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 54 | Train Loss: 2.1767 | Training accuracy: 20.385% | Validation Loss: 2.179 | Validation accuracy: 20.083% | Epoch Time: 11.71 secs
# Validation loss decreased (2.180406 --> 2.179479).  Saving model ...
# Epoch: 55 | Train Loss: 2.1732 | Training accuracy: 20.304% | Validation Loss: 2.180 | Validation accuracy: 20.104% | Epoch Time: 11.66 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 56 | Train Loss: 2.1726 | Training accuracy: 20.244% | Validation Loss: 2.197 | Validation accuracy: 18.777% | Epoch Time: 11.63 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 57 | Train Loss: 2.1704 | Training accuracy: 20.468% | Validation Loss: 2.181 | Validation accuracy: 20.000% | Epoch Time: 11.69 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 58 | Train Loss: 2.1709 | Training accuracy: 20.686% | Validation Loss: 2.182 | Validation accuracy: 19.782% | Epoch Time: 11.65 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 59 | Train Loss: 2.1700 | Training accuracy: 20.418% | Validation Loss: 2.176 | Validation accuracy: 20.404% | Epoch Time: 11.62 secs
# Validation loss decreased (2.179479 --> 2.176401).  Saving model ...
# Epoch: 60 | Train Loss: 2.1705 | Training accuracy: 20.427% | Validation Loss: 2.180 | Validation accuracy: 20.290% | Epoch Time: 11.62 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 61 | Train Loss: 2.1676 | Training accuracy: 20.603% | Validation Loss: 2.182 | Validation accuracy: 20.083% | Epoch Time: 11.76 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 62 | Train Loss: 2.1684 | Training accuracy: 20.599% | Validation Loss: 2.184 | Validation accuracy: 19.772% | Epoch Time: 11.78 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 63 | Train Loss: 2.1684 | Training accuracy: 20.468% | Validation Loss: 2.184 | Validation accuracy: 19.865% | Epoch Time: 11.64 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 64 | Train Loss: 2.1684 | Training accuracy: 20.632% | Validation Loss: 2.177 | Validation accuracy: 20.342% | Epoch Time: 11.89 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 65 | Train Loss: 2.1665 | Training accuracy: 20.812% | Validation Loss: 2.172 | Validation accuracy: 20.975% | Epoch Time: 11.64 secs
# Validation loss decreased (2.176401 --> 2.172016).  Saving model ...
# Epoch: 66 | Train Loss: 2.1658 | Training accuracy: 20.783% | Validation Loss: 2.184 | Validation accuracy: 19.772% | Epoch Time: 11.68 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 67 | Train Loss: 2.1650 | Training accuracy: 20.796% | Validation Loss: 2.179 | Validation accuracy: 20.321% | Epoch Time: 11.62 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 68 | Train Loss: 2.1650 | Training accuracy: 21.082% | Validation Loss: 2.174 | Validation accuracy: 19.927% | Epoch Time: 11.62 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 69 | Train Loss: 2.1632 | Training accuracy: 20.993% | Validation Loss: 2.178 | Validation accuracy: 20.083% | Epoch Time: 11.67 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 70 | Train Loss: 2.1618 | Training accuracy: 21.161% | Validation Loss: 2.175 | Validation accuracy: 19.741% | Epoch Time: 11.64 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 71 | Train Loss: 2.1629 | Training accuracy: 20.974% | Validation Loss: 2.179 | Validation accuracy: 19.544% | Epoch Time: 11.72 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 72 | Train Loss: 2.1559 | Training accuracy: 21.499% | Validation Loss: 2.171 | Validation accuracy: 20.031% | Epoch Time: 11.73 secs
# Validation loss decreased (2.172016 --> 2.171301).  Saving model ...
# Epoch: 73 | Train Loss: 2.1519 | Training accuracy: 21.656% | Validation Loss: 2.172 | Validation accuracy: 20.342% | Epoch Time: 11.64 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 74 | Train Loss: 2.1521 | Training accuracy: 21.766% | Validation Loss: 2.171 | Validation accuracy: 20.301% | Epoch Time: 11.65 secs
# Validation loss decreased (2.171301 --> 2.171013).  Saving model ...
# Epoch: 75 | Train Loss: 2.1500 | Training accuracy: 21.559% | Validation Loss: 2.174 | Validation accuracy: 19.679% | Epoch Time: 11.62 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 76 | Train Loss: 2.1505 | Training accuracy: 21.887% | Validation Loss: 2.169 | Validation accuracy: 20.788% | Epoch Time: 11.64 secs
# Validation loss decreased (2.171013 --> 2.168794).  Saving model ...
# Epoch: 77 | Train Loss: 2.1492 | Training accuracy: 21.629% | Validation Loss: 2.167 | Validation accuracy: 20.446% | Epoch Time: 11.71 secs
# Validation loss decreased (2.168794 --> 2.167326).  Saving model ...
# Epoch: 78 | Train Loss: 2.1488 | Training accuracy: 21.598% | Validation Loss: 2.169 | Validation accuracy: 20.715% | Epoch Time: 11.71 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 79 | Train Loss: 2.1476 | Training accuracy: 21.414% | Validation Loss: 2.172 | Validation accuracy: 20.840% | Epoch Time: 11.64 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 80 | Train Loss: 2.1458 | Training accuracy: 21.791% | Validation Loss: 2.172 | Validation accuracy: 20.311% | Epoch Time: 11.84 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 81 | Train Loss: 2.1493 | Training accuracy: 21.824% | Validation Loss: 2.170 | Validation accuracy: 20.477% | Epoch Time: 11.82 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 82 | Train Loss: 2.1476 | Training accuracy: 21.967% | Validation Loss: 2.168 | Validation accuracy: 20.529% | Epoch Time: 11.80 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 83 | Train Loss: 2.1485 | Training accuracy: 21.654% | Validation Loss: 2.181 | Validation accuracy: 20.000% | Epoch Time: 11.62 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 84 | Train Loss: 2.1416 | Training accuracy: 22.251% | Validation Loss: 2.167 | Validation accuracy: 20.498% | Epoch Time: 11.63 secs
# Validation loss decreased (2.167326 --> 2.167290).  Saving model ...
# Epoch: 85 | Train Loss: 2.1410 | Training accuracy: 22.166% | Validation Loss: 2.166 | Validation accuracy: 20.467% | Epoch Time: 11.62 secs
# Validation loss decreased (2.167290 --> 2.166293).  Saving model ...
# Epoch: 86 | Train Loss: 2.1396 | Training accuracy: 22.144% | Validation Loss: 2.167 | Validation accuracy: 20.176% | Epoch Time: 11.62 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 87 | Train Loss: 2.1390 | Training accuracy: 22.268% | Validation Loss: 2.167 | Validation accuracy: 20.301% | Epoch Time: 11.62 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 88 | Train Loss: 2.1378 | Training accuracy: 22.419% | Validation Loss: 2.169 | Validation accuracy: 20.415% | Epoch Time: 11.83 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 89 | Train Loss: 2.1383 | Training accuracy: 22.098% | Validation Loss: 2.168 | Validation accuracy: 20.425% | Epoch Time: 11.62 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 90 | Train Loss: 2.1364 | Training accuracy: 22.106% | Validation Loss: 2.170 | Validation accuracy: 19.907% | Epoch Time: 11.75 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 91 | Train Loss: 2.1370 | Training accuracy: 22.073% | Validation Loss: 2.165 | Validation accuracy: 20.529% | Epoch Time: 11.74 secs
# Validation loss decreased (2.166293 --> 2.165326).  Saving model ...
# Epoch: 92 | Train Loss: 2.1378 | Training accuracy: 22.175% | Validation Loss: 2.166 | Validation accuracy: 20.384% | Epoch Time: 11.60 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 93 | Train Loss: 2.1359 | Training accuracy: 22.177% | Validation Loss: 2.166 | Validation accuracy: 20.622% | Epoch Time: 11.67 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 94 | Train Loss: 2.1363 | Training accuracy: 22.492% | Validation Loss: 2.165 | Validation accuracy: 20.415% | Epoch Time: 11.71 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 95 | Train Loss: 2.1350 | Training accuracy: 22.419% | Validation Loss: 2.167 | Validation accuracy: 20.353% | Epoch Time: 11.68 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 96 | Train Loss: 2.1367 | Training accuracy: 22.598% | Validation Loss: 2.170 | Validation accuracy: 20.166% | Epoch Time: 11.63 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 97 | Train Loss: 2.1348 | Training accuracy: 22.681% | Validation Loss: 2.166 | Validation accuracy: 20.601% | Epoch Time: 11.68 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 98 | Train Loss: 2.1320 | Training accuracy: 22.674% | Validation Loss: 2.165 | Validation accuracy: 20.778% | Epoch Time: 11.70 secs
# Validation loss decreased (2.165326 --> 2.164511).  Saving model ...
# Epoch: 99 | Train Loss: 2.1310 | Training accuracy: 22.507% | Validation Loss: 2.164 | Validation accuracy: 20.622% | Epoch Time: 11.72 secs
# Validation loss decreased (2.164511 --> 2.163703).  Saving model ...
# Epoch: 100 | Train Loss: 2.1320 | Training accuracy: 22.444% | Validation Loss: 2.166 | Validation accuracy: 20.404% | Epoch Time: 11.82 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 101 | Train Loss: 2.1305 | Training accuracy: 22.560% | Validation Loss: 2.165 | Validation accuracy: 20.394% | Epoch Time: 11.78 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 102 | Train Loss: 2.1291 | Training accuracy: 22.890% | Validation Loss: 2.163 | Validation accuracy: 20.829% | Epoch Time: 11.65 secs
# Validation loss decreased (2.163703 --> 2.163179).  Saving model ...
# Epoch: 103 | Train Loss: 2.1299 | Training accuracy: 22.554% | Validation Loss: 2.165 | Validation accuracy: 20.560% | Epoch Time: 11.71 secs
# EarlyStopping counter: 1 out of 10
# Epoch: 104 | Train Loss: 2.1285 | Training accuracy: 22.674% | Validation Loss: 2.166 | Validation accuracy: 20.446% | Epoch Time: 11.70 secs
# EarlyStopping counter: 2 out of 10
# Epoch: 105 | Train Loss: 2.1296 | Training accuracy: 22.511% | Validation Loss: 2.166 | Validation accuracy: 20.715% | Epoch Time: 11.63 secs
# EarlyStopping counter: 3 out of 10
# Epoch: 106 | Train Loss: 2.1288 | Training accuracy: 22.797% | Validation Loss: 2.164 | Validation accuracy: 20.975% | Epoch Time: 11.64 secs
# EarlyStopping counter: 4 out of 10
# Epoch: 107 | Train Loss: 2.1283 | Training accuracy: 22.602% | Validation Loss: 2.164 | Validation accuracy: 20.467% | Epoch Time: 11.67 secs
# EarlyStopping counter: 5 out of 10
# Epoch: 108 | Train Loss: 2.1300 | Training accuracy: 22.695% | Validation Loss: 2.165 | Validation accuracy: 20.249% | Epoch Time: 11.68 secs
# EarlyStopping counter: 6 out of 10
# Epoch: 109 | Train Loss: 2.1261 | Training accuracy: 22.921% | Validation Loss: 2.164 | Validation accuracy: 20.653% | Epoch Time: 11.98 secs
# EarlyStopping counter: 7 out of 10
# Epoch: 110 | Train Loss: 2.1267 | Training accuracy: 22.845% | Validation Loss: 2.165 | Validation accuracy: 20.612% | Epoch Time: 11.75 secs
# EarlyStopping counter: 8 out of 10
# Epoch: 111 | Train Loss: 2.1244 | Training accuracy: 22.959% | Validation Loss: 2.164 | Validation accuracy: 20.373% | Epoch Time: 11.71 secs
# EarlyStopping counter: 9 out of 10
# Epoch: 112 | Train Loss: 2.1248 | Training accuracy: 23.052% | Validation Loss: 2.165 | Validation accuracy: 20.632% | Epoch Time: 11.66 secs
# EarlyStopping counter: 10 out of 10
# ==> Finished Training ...
# test accuracy: 20.992%

# %%
import torch

# Save the model
torch.save(model.state_dict(), "model.pth")

# Later to load it:
# model = CNN(...)   # create model first
# model.load_state_dict(torch.load("model.pth"))
# model.eval()

# %% [markdown]
# # Compile with Optuna

# %%
# !pip install optuna
import optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 13.6 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 20.5 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.1 colorlog-6.9.0 optuna-4.3.0

# %%
def compile_model(trial):
    # hyper-parameters
    epochs = 200
    learning_rate = trial.suggest_float("learning_rate", 1e-2, 1e-1, log=True) # log=True, will use log scale
    weight_decay = trial.suggest_float("weight_decay", 1e-5, 1e-3, log=True) # log=True, will use log scale
    batch_size = trial.suggest_int("batch_size", 64, 256) # batch_size will be between 64 and 256

    # Generate the model
    model = CNN(
        num_channel = 14,
        num_classes = 10,
        signal_length = 224,
        kernel_window_eeg = 32,
        filters_n1 = 8,
    ).to(device)

    # load data
    train_loader, valid_loader, test_loader = GetDataLoaders(x, y, batch_size=batch_size)

    # loss criterion
    criterion = nn.CrossEntropyLoss()

    # optimizer - SGD, Adam, RMSProp...
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=learning_rate,
                                               weight_decay=weight_decay)

    # Learning Rate Scheduler
    scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=50,
                                  verbose=True)

    # Early Stopping
    early_stopping = EarlyStopping(delta=0.00, patience=10, verbose=True)

    # training loop
    train_losses = []
    valid_losses = []
    for epoch in range(1, epochs + 1):
        model.train() # put in training mode
        running_loss = 0.0
        total_correct = 0
        total_images = 0
        epoch_time = time.time()
        for train_data in train_loader:
            # get the inputs
            inputs, labels = train_data
            # send them to device
            inputs = inputs.to(device)
            labels = labels.to(device)

            # forward + backward + optimize
            outputs = model(inputs) # forward pass
            loss = criterion(outputs, labels) # calculate the loss

            # always the same 3 steps
            loss.backward() # backpropagation
            optimizer.step() # update parameters
            optimizer.zero_grad() # zero the parameter gradients

            # calc accuracy
            _, predicted = torch.max(outputs.data, 1)
            total_images += labels.size(0)
            total_correct += (predicted == labels).sum().item()

            # print statistics
            running_loss += loss.data.item()

        # Normalizing the loss by the total number of train batches
        running_loss /= len(train_loader)
        train_losses.append(running_loss)

        # Calculate training and validation set accuracy of the existing model
        train_accuracy = total_correct / total_images * 100
        valid_accuracy, _, valid_loss = calculate_accuracy(model, valid_loader, device, criterion)
        valid_losses.append(valid_loss)

        log = "Epoch: {} | Train Loss: {:.4f} | Training accuracy: {:.3f}% | Validation Loss: {:.3f} | Validation accuracy: {:.3f}% | ".format(epoch
        , running_loss, train_accuracy, valid_loss, valid_accuracy)
        epoch_time = time.time() - epoch_time
        log += "Epoch Time: {:.2f} secs".format(epoch_time)
        print(log)

        # accuracy is used to track down a plateau
        scheduler.step(valid_accuracy)

        # Early Stopping
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            break

        # report back to Optuna how far it is (epoch-wise) into the trial and how
        # well it is doing (validation accuracy)
        trial.report(valid_accuracy, epoch)

        # then, Optuna can decide if the trial should be pruned
        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()

    print('==> Finished Training ...')

    # print loss curves
    plt.plot(train_losses, label='Train Loss')
    plt.plot(valid_losses, label='Validation Loss')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss')

    # calculate accuracy and confusion matrix
    test_accuracy, confusion_matrix, _ = calculate_accuracy(model, test_loader, device, criterion)
    print("test accuracy: {:.3f}%".format(test_accuracy))

    # plot confusion matrix
    fig, ax = plt.subplots(1,1,figsize=(8,6))
    ax.matshow(confusion_matrix, aspect='auto', vmin=0, vmax=1000, cmap=plt.get_cmap('Blues'))
    plt.ylabel('Actual Category')
    plt.yticks(range(10), range(10))
    plt.xlabel('Predicted Category')
    plt.xticks(range(10), range(10))
    plt.show()

    return valid_accuracy

# %%
# Compile with Optuna
# sampler = optuna.samplers.TPESampler()
# study = optuna.create_study(study_name="EEG-CNN", direction="maximize", sampler=sampler)
# study.optimize(compile_model, n_trials=2)
# pruned_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.PRUNED]
# complete_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
# print("Study statistics: ")
# print(" Number of finished trials: ", len(study.trials))
# print(" Number of pruned trials: ", len(pruned_trials))
# print(" Number of complete trials: ", len(complete_trials))
# print("Best trial:")
# trial = study.best_trial
# print(" Value: ", trial.value)
# print(" Params: ")
# for key, value in trial.params.items():
#  print(" {}: {}".format(key, value))

# %%
 # optuna.visualization.plot_param_importances(study)
